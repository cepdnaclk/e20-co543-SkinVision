# %%
## Step 01
## Import Necessary libraries

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shutil
import zipfile
import gdown
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import f1_score
import seaborn as sns

# %%
## Step 02
## Load data from Google Drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/Ishan\ Thathsara/TrainingDataFull.zip -d /content/data_skintone1
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data_skintone1/data_skintone/mid-light/69481872.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69482913.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69488326.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69493327.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69494779.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69498101.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69523253.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69524236.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69526398.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69526797.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69557438.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69563406.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69588825.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69589160.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69597201.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69599704.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69609187.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69624466.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69646560.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69656938.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69694643.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69696104.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69737113.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69738833.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69741438.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69750242.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69758443.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69759068.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69782183.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/6978631.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69853476.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69872072.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69878943.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69881826.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69898393.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69906026.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69909739.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69922837.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69943953.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69980130.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69984822.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/69991013.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70003326.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70011067.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70033599.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70047121.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70059434.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70091474.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70091487.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70132188.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70213476.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70219888.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70233837.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70234002.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70248858.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70266269.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70287002.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70311079.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70324789.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70339920.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70343991.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70345023.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70356778.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70357568.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70388008.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70388863.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70394259.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70396745.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70403731.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70440588.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70443976.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70448868.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70454940.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70458811.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70462243.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70499243.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70506513.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70513300.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70519653.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70521065.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70523123.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70529099.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70554201.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70559007.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70572702.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70589055.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70590062.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70596070.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70596410.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70600463.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70628939.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70650476.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70655445.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70656371.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70657882.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70681758.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70685830.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70691376.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70703913.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70710029.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70710034.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70711567.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70726601.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70741951.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70766532.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70773697.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70773725.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70774307.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70793763.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70794071.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70821069.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70823450.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70860250.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70862356.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70867713.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70870995.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70883123.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70884754.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70897848.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70906981.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70907829.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70918063.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70929917.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70930037.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70930310.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/70991596.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71015340.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71038322.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71040633.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71052912.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71055983.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71062697.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71068644.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71090138.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71178004.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71242773.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71262538.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71298963.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71381534.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71406780.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71427706.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71432638.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71454496.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71454865.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71464314.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71468555.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71468761.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71470658.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71517258.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71519517.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71525787.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71547792.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71551882.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71565314.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71603131.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71604109.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71605207.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71671508.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71677845.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71768370.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/7181088.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71823043.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71830621.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71867460.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71885251.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71904024.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71911056.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71949267.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71949731.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71972196.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71972402.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71976767.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71990256.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/71992450.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72004587.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72034035.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72039046.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72047823.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72073409.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72079852.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72079940.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72090734.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72105552.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72122859.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72128946.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72152201.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72157689.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72191519.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72201558.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72221261.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72260559.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72270700.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72290658.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72310000.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72345758.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72354914.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72355557.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72362158.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72364657.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72367679.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72388277.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72415182.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72462626.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72471532.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72485384.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72491890.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72501076.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72502289.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72510331.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72598540.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72619044.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72688314.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72695744.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72726986.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72767602.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72883787.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72883851.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72915027.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/72932001.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/7295903.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73003022.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73097909.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73098794.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73151797.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73169333.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73222091.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73270174.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73270681.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73274623.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73319740.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73319893.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73344597.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73347730.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73357097.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73357276.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73385515.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73392182.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73404217.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73470336.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73533683.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/7355216.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73569066.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73571442.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73583288.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73615991.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73626039.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73627332.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73643967.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73668833.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73676582.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73808806.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73847245.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73910471.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/73998728.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74049213.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74173391.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74247563.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74264481.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74284005.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74353664.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74401955.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74411891.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74420479.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74451064.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74484014.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74525066.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74526815.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74529082.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74582564.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74584654.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74596925.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74598761.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74627914.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74639472.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74640966.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74641009.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74641599.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74666892.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74753344.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74760190.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74802688.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74803583.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74805592.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74805952.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74809503.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74811306.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74820062.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74836898.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74838766.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74840539.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74847815.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74850413.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74862396.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74920487.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74938652.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74938716.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74976968.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74977101.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74978915.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74979294.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74979652.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74981767.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74984898.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/74985665.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75007028.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75007167.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75014783.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75018862.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75023816.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75027325.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75069946.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75104384.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75105580.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75112735.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75122832.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75133864.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75137527.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75139193.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75149224.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75166390.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75176488.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75216004.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75228010.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75240862.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75242010.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75243162.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75259617.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75266531.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75274115.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75275559.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75304233.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75315224.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75320571.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75330649.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75360344.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75371474.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75372559.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75379986.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75404527.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75405548.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75418494.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75419449.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75423620.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75424783.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75469521.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75469664.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75499641.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75504644.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75520918.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75520932.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75520982.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75535793.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75569307.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75577364.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75577396.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75577433.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75584612.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75587063.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75605805.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75624506.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75625405.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75651602.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75665520.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75668838.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75670901.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75671284.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75721084.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75725733.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75727238.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75728178.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75756075.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75756337.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75756348.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75780239.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75781858.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75783925.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75787151.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75792288.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75797625.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75797832.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75799546.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75809672.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75821997.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75841045.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75871707.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75878496.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75891119.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75907307.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75936719.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75938105.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75945720.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75957877.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75975596.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75997088.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/75997535.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76007696.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76014323.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/7603325.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76037959.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76041991.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76053473.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76056548.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76075277.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76082524.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76089915.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76107263.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76174399.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76176068.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76187444.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76187637.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76187644.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76187674.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76196627.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76211180.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76255823.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76257410.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76260922.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76262687.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76274865.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76284696.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76382417.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76412669.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76421681.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76432616.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76480140.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76505112.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76515623.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76532859.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76561964.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76563602.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76585124.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76620877.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76652311.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76654008.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76654068.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76659122.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76774163.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76777448.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76781753.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76787856.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76787878.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76796542.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76816481.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76826541.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76828924.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76832900.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76868896.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76868901.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76868903.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76879105.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76886102.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76914342.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76956169.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/76987287.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77011177.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77013753.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77066333.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77115625.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77137895.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77174067.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77190189.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77227238.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77241785.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77258019.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77262720.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77271881.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77272387.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77333532.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77340507.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77382138.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77409232.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77421062.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77433336.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77440560.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77441193.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77458390.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77467560.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77480971.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77481156.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77488013.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77488026.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77507625.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77508396.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77513868.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77526931.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77533363.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77573574.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77584704.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77689724.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77699481.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77731261.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77817563.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/7782700.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77847919.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77863350.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77869174.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77900232.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77910043.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77916195.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77920472.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77929015.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77963359.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77971252.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77971394.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/77996829.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78001901.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78040442.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78046300.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78057386.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78126083.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78142723.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78147248.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78174290.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78216435.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78366803.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78389931.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78404348.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78416721.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78420283.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78426105.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78460450.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78468419.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78468589.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78489669.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78519992.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78520001.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78615870.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78675928.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78676150.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78690855.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78720189.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78723506.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78763344.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78770647.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78772546.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78782555.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78833680.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78838707.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78860101.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78863741.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78908983.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78913856.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78913954.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78919581.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78922085.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78937407.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78966981.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/78968144.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79002944.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79003251.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79007294.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79072551.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79088228.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79090311.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79091826.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79092904.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79104585.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79109271.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79111214.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79127133.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79146809.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79151344.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79168982.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79196433.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79204035.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79207109.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79218981.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79275674.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79295698.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79307733.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79311388.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79313183.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79366746.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79383258.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79392549.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79399285.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79440422.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79447913.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79448028.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79449022.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79584059.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79593307.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79636378.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79641182.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79680225.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79695828.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79775686.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/79904291.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/802382.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80305144.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80320103.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80327021.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80340789.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80394994.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80426193.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80436237.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80447483.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80458320.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80478636.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80481350.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80501612.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80534958.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80572460.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80578077.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80676148.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80744838.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80810506.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80829560.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80867346.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80880732.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80898895.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80898896.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80957075.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80959080.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/80965746.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81057789.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81060945.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81062874.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81106588.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81107421.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81109014.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81128411.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81157029.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81161998.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81162080.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81165740.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81173334.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81194441.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81231039.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81236754.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/81270316.jpg
# ...
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5716.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5718.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5751.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5757.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5783.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5822.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5824.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_585.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5858.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5860.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5873.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_588.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5888.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5889.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5899.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5908.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5922.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5949.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5956.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5958.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_598.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_5988.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6025.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6059.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_607.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_608.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6101.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6123.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6135.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6155.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6169.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6209.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_621.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6221.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6241.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6260.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6268.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_627.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6270.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6356.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_638.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6389.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6398.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6400.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6404.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6417.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6427.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6435.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6446.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6452.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6461.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6481.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6521.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6537.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6545.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6549.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6566.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6568.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6576.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6602.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6634.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6649.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6655.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6677.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6680.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6688.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6696.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6722.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6747.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6761.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6780.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6799.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6831.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6848.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6853.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6861.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6868.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6877.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6915.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6916.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6920.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6929.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6936.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6943.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_6950.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7016.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7038.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7088.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7090.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7091.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7121.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7126.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7141.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_716.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7160.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7173.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7174.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7175.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7180.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7198.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7206.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7211.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7224.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7227.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7249.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7252.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7283.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7286.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7289.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7318.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_736.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7365.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7403.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7407.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7426.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7436.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_744.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7449.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_747.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_750.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7503.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7504.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7507.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7509.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7519.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7600.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7603.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7625.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7637.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7710.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7716.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7733.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7759.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7793.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7809.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7821.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7844.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7848.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7911.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_7991.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8000.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8013.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8044.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_808.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8094.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8119.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_818.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8187.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8196.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8211.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_823.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8233.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8249.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8259.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_827.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8319.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8334.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8371.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8372.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8377.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8416.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8421.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_844.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8521.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8549.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8560.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_861.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8612.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8623.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8633.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8675.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8687.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_87.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8705.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8733.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_874.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_875.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8755.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8771.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8833.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8835.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8917.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8933.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_8987.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9121.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_914.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9161.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9263.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_932.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9517.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9555.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9559.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_957.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9591.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9599.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9653.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9711.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9737.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9741.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_977.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9783.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_986.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_991.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_9923.jpg
#   inflating: /content/data_skintone1/data_skintone/mid-light/image_993.jpg

# %%
## Step 03
## Organize the Dataset

# Define the dataset directory
dataset_dir = '/content/data_skintone1/data_skintone'

# Update categories based on actual directory names
categories = ['dark', 'light', 'mid-dark', 'mid-light']

# Create directories for train and validation split
train_dir = '/content/data_skintone1/data_skintone/working/train'
valid_dir = '/content/data_skintone1/data_skintone/working/val'

for category in categories:
    os.makedirs(os.path.join(train_dir, category), exist_ok=True)
    os.makedirs(os.path.join(valid_dir, category), exist_ok=True)

# Load image paths and labels
image_paths = []
labels = []

for category in categories:
    category_path = os.path.join(dataset_dir, category)
    for img_name in os.listdir(category_path):
        image_paths.append(os.path.join(category_path, img_name))
        labels.append(category)

# Split data into train and validation sets
train_paths, val_paths, train_labels, val_labels = train_test_split(image_paths, labels, test_size=0.2, stratify=labels)

# Move the images to train and validation directories
for img, label in zip(train_paths, train_labels):
    shutil.copy(img, os.path.join(train_dir, label, os.path.basename(img)))

for img, label in zip(val_paths, val_labels):
    shutil.copy(img, os.path.join(valid_dir, label, os.path.basename(img)))

print("Data has been successfully split and organized.")
# Out:
# Data has been successfully split and organized.

# %%
## Step 04
## Data augmentation and preprocessing

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    zoom_range=0.2,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.2],
    shear_range=0.2,
    fill_mode='nearest'
)


valid_datagen = ImageDataGenerator(rescale=1./255)

# Load train and validation data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 28663 images belonging to 4 classes.
# Found 7166 images belonging to 4 classes.

# %%
# Custom F1-score metric for Keras

import tensorflow as tf

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * (p * r) / (p + r + tf.keras.backend.epsilon())

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

# %%
## Step 05
## Model creation using Transfer Learning

from tensorflow.keras.layers import Dropout

# Load the MobileNetV2 model with pre-trained ImageNet weights
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers[-2:]:
    layer.trainable = True


x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(len(categories), activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), AUC(name='auc'), F1Score(name='f1_score')])

# Print the model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 512)            │        655,872 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 4)              │          2,052 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,915,908 (11.12 MB)
#  Trainable params: 2,881,796 (10.99 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
# Check class indices to ensure 4 classes
print("Class indices:", train_generator.class_indices)
print("Number of classes:", train_generator.num_classes)
# Out:
# Class indices: {'dark': 0, 'light': 1, 'mid-dark': 2, 'mid-light': 3}
# Number of classes: 4

# %%
## Step 06
## Train the model

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=3, min_delta=0.001, restore_best_weights=True)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-5
)

checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_loss',
    save_best_only=True,
    mode='min'
)

# Train the model
history = model.fit(
    train_generator,
    epochs=40,
    validation_data=validation_generator,
    callbacks=[early_stopping, lr_scheduler, checkpoint]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.6865 - auc: 0.9033 - f1_score: 0.6668 - loss: 0.7266 - precision: 0.7266 - recall: 0.6170
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 526s 532ms/step - accuracy: 0.6865 - auc: 0.9034 - f1_score: 0.6669 - loss: 0.7265 - precision: 0.7266 - recall: 0.6170 - val_accuracy: 0.3323 - val_auc: 0.6085 - val_f1_score: 0.3308 - val_loss: 5.5273 - val_precision: 0.3338 - val_recall: 0.3278 - learning_rate: 0.0010
# Epoch 2/40
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.7931 - auc: 0.9556 - f1_score: 0.7880 - loss: 0.4876 - precision: 0.8076 - recall: 0.7693
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 450s 502ms/step - accuracy: 0.7931 - auc: 0.9556 - f1_score: 0.7880 - loss: 0.4876 - precision: 0.8076 - recall: 0.7693 - val_accuracy: 0.7007 - val_auc: 0.8706 - val_f1_score: 0.7011 - val_loss: 1.4680 - val_precision: 0.7034 - val_recall: 0.6989 - learning_rate: 0.0010
# Epoch 3/40
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8033 - auc: 0.9611 - f1_score: 0.8007 - loss: 0.4537 - precision: 0.8149 - recall: 0.7870
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 449s 501ms/step - accuracy: 0.8033 - auc: 0.9611 - f1_score: 0.8007 - loss: 0.4537 - precision: 0.8149 - recall: 0.7870 - val_accuracy: 0.6929 - val_auc: 0.8910 - val_f1_score: 0.6927 - val_loss: 1.4182 - val_precision: 0.6947 - val_recall: 0.6908 - learning_rate: 0.0010
# Epoch 4/40
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 448s 500ms/step - accuracy: 0.8178 - auc: 0.9657 - f1_score: 0.8156 - loss: 0.4251 - precision: 0.8264 - recall: 0.8051 - val_accuracy: 0.7007 - val_auc: 0.8590 - val_f1_score: 0.7013 - val_loss: 1.9155 - val_precision: 0.7026 - val_recall: 0.7001 - learning_rate: 0.0010
# Epoch 5/40
# 246/896 ━━━━━━━━━━━━━━━━━━━━ 5:19 491ms/step - accuracy: 0.8244 - auc: 0.9692 - f1_score: 0.8196 - loss: 0.4016 - precision: 0.8313 - recall: 0.8082

# %%
# Plot training & validation accuracy, loss, precision, recall, AUC, and F1-score
plt.figure(figsize=(15, 8))

# Accuracy plot
plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(2, 3, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# Precision plot
plt.subplot(2, 3, 3)
plt.plot(history.history['precision'], label='Train Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(loc='lower right')

# Recall plot
plt.subplot(2, 3, 4)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(loc='lower right')

# AUC plot
plt.subplot(2, 3, 5)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(loc='lower right')

# F1 Score plot
plt.subplot(2, 3, 6)
plt.plot(history.history['f1_score'], label='Train F1-Score')
plt.plot(history.history['val_f1_score'], label='Validation F1-Score')
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
# Evaluate the model on validation data
validation_results = model.evaluate(validation_generator)

# Extract metrics
validation_loss = validation_results[0]
validation_accuracy = validation_results[1]
validation_precision = validation_results[2]
validation_recall = validation_results[3]
validation_auc = validation_results[4]
validation_f1_score = validation_results[5]

# Print validation metrics
print(f"Validation Loss: {validation_loss:.4f}")
print(f"Validation Accuracy: {validation_accuracy * 100:.2f}%")
print(f"Validation Precision: {validation_precision:.4f}")
print(f"Validation Recall: {validation_recall:.4f}")
print(f"Validation AUC: {validation_auc:.4f}")
print(f"Validation F1-Score: {validation_f1_score:.4f}")
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.8187 - auc: 0.9688 - f1_score: 0.8170 - loss: 0.4071 - precision: 0.8280 - recall: 0.8062
# Validation Loss: 0.4092
# Validation Accuracy: 82.03%
# Validation Precision: 0.8295
# Validation Recall: 0.8085
# Validation AUC: 0.9686
# Validation F1-Score: 0.8189

# %%
# Predict the classes on validation data
Y_pred = model.predict(validation_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get true classes
y_true = validation_generator.classes

# Check unique predicted and true classes
unique_pred_classes = np.unique(y_pred)
unique_true_classes = np.unique(y_true)

print(f"Unique predicted classes: {unique_pred_classes}")
print(f"Unique true classes: {unique_true_classes}")

# Adjust target names to match actual predicted classes
# This ensures the classification report will reflect only the predicted classes
actual_categories = [categories[i] for i in unique_pred_classes]

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=actual_categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification report with adjusted labels
print(classification_report(y_true, y_pred, labels=unique_pred_classes, target_names=actual_categories))
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 25s 93ms/step
# Unique predicted classes: [0 1 2 3]
# Unique true classes: [0 1 2 3]
#               precision    recall  f1-score   support
#
#         dark       0.23      0.24      0.23      1728
#        light       0.28      0.22      0.25      1954
#     mid-dark       0.29      0.30      0.29      2115
#    mid-light       0.19      0.24      0.21      1369
#
#     accuracy                           0.25      7166
#    macro avg       0.25      0.25      0.25      7166
# weighted avg       0.25      0.25      0.25      7166

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Number of classes
num_classes = 4
class_labels = ['dark', 'light', 'mid-dark', 'mid-light']  # Adjust according to your labels

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()  # Flatten for easy indexing

# Loop through each class
for i in range(num_classes):
    precision, recall, _ = precision_recall_curve(y_true == i, Y_pred[:, i])  # Compute PR curve

    axes[i].plot(recall, precision, marker='.')
    axes[i].set_title(f'Precision-Recall Curve ({class_labels[i]})')
    axes[i].set_xlabel('Recall')
    axes[i].set_ylabel('Precision')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Number of classes
num_classes = 4
class_labels = ['dark', 'light', 'mid-dark', 'mid-light']  # Adjust according to your labels

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()  # Flatten for easy indexing

# Loop through each class
for i in range(num_classes):
    # Convert y_true to binary for the current class
    y_true_binary = (y_true == i).astype(int)

    # Get predicted probabilities for the current class
    y_score = Y_pred[:, i]

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(y_true_binary, y_score)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    axes[i].plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
    axes[i].plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random classifier line
    axes[i].set_title(f'ROC Curve ({class_labels[i]})')
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
#Class-wise Performance (Bar Chart)

from sklearn.metrics import classification_report
import pandas as pd

report = classification_report(y_true, y_pred, target_names=categories, output_dict=True)
df_report = pd.DataFrame(report).transpose()

df_report[['precision', 'recall', 'f1-score']].iloc[:-1].plot(kind='bar', figsize=(10, 5))
plt.title('Class-wise Performance')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()
